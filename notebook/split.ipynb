# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("C:\\Users\\sneha\\Desktop\\AI-Powered-Sustainable-Packaging-Recommendation-System\\data\\processed\\engineered_features.csv")

train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df["Material Type"]  # if exists
)

print(train_df.shape, test_df.shape)
# Out:
# (323, 27) (81, 27)

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
print(train_df["Material Type"].value_counts(normalize=True))
print(test_df["Material Type"].value_counts(normalize=True))
# Out:
# Material Type
# Plastic            0.492260
# Cardboard          0.343653
# Paper/Bio-Based    0.092879
# Steel              0.071207
# Name: proportion, dtype: float64
# Material Type
# Plastic            0.493827
# Cardboard          0.345679
# Paper/Bio-Based    0.086420
# Steel              0.074074
# Name: proportion, dtype: float64
