# %%
import os
os.chdir(r"C:\Users\sneha\Desktop\AI-Powered-Sustainable-Packaging-Recommendation-System")

# %%
import pandas as pd

df = pd.read_csv("data/processed/engineered_features.csv")

df.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Material ID                             404 non-null    object
#  1   Packaging Type                          404 non-null    object
#  2   Material Type                           404 non-null    object
#  3   Suitable Product Categories             404 non-null    object
#  4   Recommended Packaging Use Cases         404 non-null    object
#  5   Supplier Region                         404 non-null    object
#  6   Recyclability (%)                       404 non-null    int64
#  7   Recyclability Category                  404 non-null    object
#  8   Recycled Content (%)                    404 non-null    float64
#  9   Reusability (%)                         404 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Material ID                               0
# Packaging Type                            0
# Material Type                             0
# Suitable Product Categories               0
# Recommended Packaging Use Cases           0
# Supplier Region                           0
# Recyclability (%)                         0
# Recyclability Category                    0
# Recycled Content (%)                      0
# Reusability (%)                           0
# Biodegradation Time (days)                0
# End-of-Life Disposal (%)                  0
# Carbon Footprint (kg CO2/unit)            0
# CO2 Emission per kg (estimated)           0
# Waste Reduction Impact (%)                0
# Sustainability Target Progress (%)        0
# Load Handling Score                       0
# Moisture Resistance Score                 0
# Thermal Resistance Score                  0
# Cost per Unit (USD)                       0
# Annual Usage (units)                      0
# ...

# %%
# Example (adjust column name if needed)
df["recommended_material"] = df["Material Type"]

# %%
df.columns
# Out:
# Index(['material_id', 'packaging_type', 'material_type',
#        'suitable_product_categories', 'recommended_packaging_use_cases',
#        'supplier_region', 'recyclability_%', 'recyclability_category',
#        'recycled_content_%', 'reusability_%', 'biodegradation_time_days',
#        'end-of-life_disposal_%', 'carbon_footprint_kg_co2_unit',
#        'co2_emission_per_kg_estimated', 'waste_reduction_impact_%',
#        'sustainability_target_progress_%', 'load_handling_score',
#        'moisture_resistance_score', 'thermal_resistance_score',
#        'cost_per_unit_usd', 'annual_usage_units', 'total_material_weight_tons',
#        'supplier_sustainability_compliance_%', 'cii', 'cei', 'mss',
#        'final_recommendation_score', 'recommended_material'],
#       dtype='object')

# %%
feature_cols = ['material_id', 'packaging_type', 'material_type',
       'suitable_product_categories', 'recommended_packaging_use_cases',
       'supplier_region', 'recyclability_%', 'recyclability_category',
       'recycled_content_%', 'reusability_%', 'biodegradation_time_days',
       'end-of-life_disposal_%', 'carbon_footprint_kg_co2_unit',
       'co2_emission_per_kg_estimated', 'waste_reduction_impact_%',
       'sustainability_target_progress_%', 'load_handling_score',
       'moisture_resistance_score', 'thermal_resistance_score',
       'cost_per_unit_usd', 'annual_usage_units', 'total_material_weight_tons',
       'supplier_sustainability_compliance_%', 'cii', 'cei', 'mss',
       'final_recommendation_score', 'recommended_material'],

# %%
feature_cols = [
    col for col in df.columns
    if col not in ['Material ID', 'Packaging Type', 'Material Type',
                   'Suitable Product Categories',
                   'Recommended Packaging Use Cases',
                   'Supplier Region',
                   'Recyclability Category',
                   'recommended_material']
]

# %%
X = df[feature_cols]
y = df['recommended_material']

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (404, 27)
# y shape: (404,)

# %%
list(df.columns)
# Out:
# ['Material ID',
#  'Packaging Type',
#  'Material Type',
#  'Suitable Product Categories',
#  'Recommended Packaging Use Cases',
#  'Supplier Region',
#  'Recyclability (%)',
#  'Recyclability Category',
#  'Recycled Content (%)',
#  'Reusability (%)',
#  'Biodegradation Time (days)',
#  'End-of-Life Disposal (%)',
#  'Carbon Footprint (kg CO2/unit)',
#  'CO2 Emission per kg (estimated)',
#  'Waste Reduction Impact (%)',
#  'Sustainability Target Progress (%)',
#  'Load Handling Score',
#  'Moisture Resistance Score',
#  'Thermal Resistance Score',
#  'Cost per Unit (USD)',
#  'Annual Usage (units)',
#  'Total Material Weight (tons)',
#  'Supplier Sustainability Compliance (%)',
#  'CII',
#  'CEI',
#  'MSS',
#  'Final_Recommendation_Score',
#  'recommended_material']

# %%
X.to_csv("data/processed/X_raw.csv", index=False)
y.to_csv("data/processed/y_raw.csv", index=False)

print("X_raw.csv and y_raw.csv saved successfully")
# Out:
# X_raw.csv and y_raw.csv saved successfully
