# %% [markdown]
# This notebook creates sustainability and cost-based features
# used for packaging material recommendation.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\sneha\\Desktop\\AI-Powered-Sustainable-Packaging-Recommendation-System\\data\\processed\\engineered_features.csv")
df.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
df[["CII", "CEI", "MSS", "Final_Recommendation_Score"]].describe()
# Out:
#               CII         CEI    MSS  Final_Recommendation_Score
# count  404.000000  404.000000  404.0                  404.000000
# mean    95.743837   69.161386   10.0                   62.047327
# std      3.996198    0.858497    0.0                    1.833266
# min     81.510000   65.500000   10.0                   55.250000
# 25%     93.145000   68.700000   10.0                   60.817500
# 50%     95.945000   69.400000   10.0                   62.210000
# 75%     99.690000   69.900000   10.0                   63.850000
# max    100.000000   70.000000   10.0                   64.000000

# %%
import os

os.makedirs("C:\\Users\\sneha\\Desktop\\AI-Powered-Sustainable-Packaging-Recommendation-System\\data\\final", exist_ok=True)
print("data/final folder created ✔")
# Out:
# data/final folder created ✔
