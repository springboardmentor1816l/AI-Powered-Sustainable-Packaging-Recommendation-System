# %%
import pandas as pd
import os

os.makedirs("data/final", exist_ok=True)

# 1️⃣ CLEANED DATASET
cleaned_df = pd.read_csv(r"C:\Users\Ranjit\OneDrive\Desktop\AI-Powered-Sustainable-Packaging-Recommendation-System\data\processed\material_cleaned.csv")
cleaned_df.to_parquet(
    "materials_cleaned.parquet",
    index=False
)

# 2️⃣ ENGINEERED DATASET (documented features – placeholder)
engineered_df = cleaned_df.copy()

engineered_df["CO2_Impact_Index"] = 0
engineered_df["Cost_Efficiency_Index"] = 0
engineered_df["Material_Suitability_Score"] = 0

engineered_df.to_parquet(
    "materials_engineered.parquet",
    index=False
)

# 3️⃣ MODEL-READY DATASET
model_ready_df = pd.read_csv(r"C:\Users\Ranjit\OneDrive\Desktop\AI-Powered-Sustainable-Packaging-Recommendation-System\data\model_ready\materials_final_encoded.csv")
model_ready_df.to_parquet(
    "materials_model_ready.parquet",
    index=False
)

print("✅ Parquet files created successfully")
# Out:
# ✅ Parquet files created successfully
