# %%
import pandas as pd

df = pd.read_csv("cleaned_integrated_materials.csv")
df.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# 1      Void-fill and cushioning for fragile products            APAC
# 2  Secure, high-load international shipping and l...        AMERICAS
# 3      Void-fill and cushioning for fragile products             ROW
# 4      Void-fill and cushioning for fragile products           LATAM
#
#    Recyclability (%) Recyclability Category  Recycled Content (%)  \
# 0               98.0                   High                  79.0
# 1              100.0                   High                  93.0
# 2               87.0                   High                  78.0
# 3              100.0                   High                  89.0
# 4              100.0                   High                  92.0
#
#    Reusability (%)  ...  CO2 Emission per kg (estimated)  \
# 0             49.0  ...                             0.54
# 1             31.0  ...                             0.32
# 2            100.0  ...                             3.25
# 3             31.0  ...                             0.31
# 4             28.0  ...                             0.31
#
#    Waste Reduction Impact (%)  Sustainability Target Progress (%)  \
# 0                        61.0                                88.0
# 1                        68.0                                98.0
# 2                        85.0                                79.0
# 3                        69.0                                87.0
# 4                        61.0                                89.0
#
#    Load Handling Score  Moisture Resistance Score  Thermal Resistance Score  \
# 0                  6.0                        5.0                       4.0
# 1                  3.0                        3.0                       3.0
# 2                  8.0                        9.0                       9.0
# 3                  1.0                        1.0                       4.0
# 4                  3.0                        2.0                       3.0
#
#    Cost per Unit (USD)  Annual Usage (units)  Total Material Weight (tons)  \
# 0                 2.24              101260.0                         790.0
# 1                 1.82               73961.0                         545.0
# 2                25.00               14649.0                        4979.0
# 3                 2.43               75036.0                         656.0
# 4                 1.69               69209.0                         549.0
#
#    Supplier Sustainability Compliance (%)
# 0                                    85.0
# 1                                    88.0
# 2                                    88.0
# 3                                    81.0
# 4                                    81.0
#
# [5 rows x 23 columns]

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
    .str.replace("%", "percent", regex=False)
)
df.columns
# Out:
# Index(['material_id', 'packaging_type', 'material_type',
#        'suitable_product_categories', 'recommended_packaging_use_cases',
#        'supplier_region', 'recyclability_percent', 'recyclability_category',
#        'recycled_content_percent', 'reusability_percent',
#        'biodegradation_time_days', 'end-of-life_disposal_percent',
#        'carbon_footprint_kg_co2/unit', 'co2_emission_per_kg_estimated',
#        'waste_reduction_impact_percent',
#        'sustainability_target_progress_percent', 'load_handling_score',
#        'moisture_resistance_score', 'thermal_resistance_score',
#        'cost_per_unit_usd', 'annual_usage_units', 'total_material_weight_tons',
#        'supplier_sustainability_compliance_percent'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
    .str.replace("%", "percent", regex=False)
)
df.columns
# Out:
# Index(['material_id', 'packaging_type', 'material_type',
#        'suitable_product_categories', 'recommended_packaging_use_cases',
#        'supplier_region', 'recyclability_percent', 'recyclability_category',
#        'recycled_content_percent', 'reusability_percent',
#        'biodegradation_time_days', 'end-of-life_disposal_percent',
#        'carbon_footprint_kg_co2/unit', 'co2_emission_per_kg_estimated',
#        'waste_reduction_impact_percent',
#        'sustainability_target_progress_percent', 'load_handling_score',
#        'moisture_resistance_score', 'thermal_resistance_score',
#        'cost_per_unit_usd', 'annual_usage_units', 'total_material_weight_tons',
#        'supplier_sustainability_compliance_percent'],
#       dtype='object')

# %%
target = "material_type"
y = df[target]
y.head()
# Out:
# 0          Cardboard
# 1    Paper/Bio-Based
# 2              Steel
# 3    Paper/Bio-Based
# 4    Paper/Bio-Based
# Name: material_type, dtype: object

# %%
X = df.drop(columns=[target])
X.head()
# Out:
#   material_id                            packaging_type  \
# 0    MAT_0001                           Cardboard Boxes
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)
# 2    MAT_0003                  Steel Racks & Containers
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)
#
#                          suitable_product_categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      recommended_packaging_use_cases supplier_region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# 1      Void-fill and cushioning for fragile products            APAC
# 2  Secure, high-load international shipping and l...        AMERICAS
# 3      Void-fill and cushioning for fragile products             ROW
# 4      Void-fill and cushioning for fragile products           LATAM
#
#    recyclability_percent recyclability_category  recycled_content_percent  \
# 0                   98.0                   High                      79.0
# 1                  100.0                   High                      93.0
# 2                   87.0                   High                      78.0
# 3                  100.0                   High                      89.0
# 4                  100.0                   High                      92.0
#
#    reusability_percent  biodegradation_time_days  ...  \
# 0                 49.0                     188.0  ...
# 1                 31.0                      65.0  ...
# 2                100.0                  180208.0  ...
# 3                 31.0                      65.0  ...
# 4                 28.0                     122.0  ...
#
#    co2_emission_per_kg_estimated  waste_reduction_impact_percent  \
# 0                           0.54                            61.0
# 1                           0.32                            68.0
# 2                           3.25                            85.0
# 3                           0.31                            69.0
# 4                           0.31                            61.0
#
#    sustainability_target_progress_percent  load_handling_score  \
# 0                                    88.0                  6.0
# 1                                    98.0                  3.0
# 2                                    79.0                  8.0
# 3                                    87.0                  1.0
# 4                                    89.0                  3.0
#
#    moisture_resistance_score  thermal_resistance_score  cost_per_unit_usd  \
# 0                        5.0                       4.0               2.24
# 1                        3.0                       3.0               1.82
# 2                        9.0                       9.0              25.00
# 3                        1.0                       4.0               2.43
# 4                        2.0                       3.0               1.69
#
#    annual_usage_units  total_material_weight_tons  \
# 0            101260.0                       790.0
# 1             73961.0                       545.0
# 2             14649.0                      4979.0
# 3             75036.0                       656.0
# 4             69209.0                       549.0
#
#    supplier_sustainability_compliance_percent
# 0                                        85.0
# 1                                        88.0
# 2                                        88.0
# 3                                        81.0
# 4                                        81.0
#
# [5 rows x 22 columns]

# %%
X.to_csv("X_raw.csv", index=False)
y.to_csv("y_raw.csv", index=False)

print("SUCCESS: Files saved")
# Out:
# SUCCESS: Files saved
