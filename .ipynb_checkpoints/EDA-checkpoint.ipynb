# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Load Dataset

# %%
datam=pd.read_csv(".\data\materials_dataset.csv")
datap=pd.read_csv(".\data\packaging_products_sample.csv")
dfm=pd.DataFrame(datam)
dfp=pd.DataFrame(datap)

# %%
dfm.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
dfp.head()
# Out:
#   product_id            product_name    category  product_weight  \
# 0  PRD_20001      Water Bottle SKU-0      Sports        0.726424
# 1  PRD_20002  Area Rug (Small) SKU-1  Home Goods        1.425100
# 2  PRD_20003          Yoga Mat SKU-2      Sports        0.713777
# 3  PRD_20004    Hair Spray Can SKU-3   Cosmetics        0.387991
# 4  PRD_20005          Backpack SKU-4     Apparel        0.466723
#
#    fragility_index shipping_type
# 0                4           Air
# 1                5           Sea
# 2                2           Sea
# 3                3           Air
# 4                2           Sea

# %% [markdown]
# # 2. Explore Structure

# %% [markdown]
# # 2.1 Materials

# %%
dfm.shape
# Out:
# (404, 23)

# %%
dfm.columns
# Out:
# Index(['Material ID', 'Packaging Type', 'Material Type',
#        'Suitable Product Categories', 'Recommended Packaging Use Cases',
#        'Supplier Region', 'Recyclability (%)', 'Recyclability Category',
#        'Recycled Content (%)', 'Reusability (%)', 'Biodegradation Time (days)',
#        'End-of-Life Disposal (%)', 'Carbon Footprint (kg CO2/unit)',
#        'CO2 Emission per kg (estimated)', 'Waste Reduction Impact (%)',
#        'Sustainability Target Progress (%)', 'Load Handling Score',
#        'Moisture Resistance Score', 'Thermal Resistance Score',
#        'Cost per Unit (USD)', 'Annual Usage (units)',
#        'Total Material Weight (tons)',
#        'Supplier Sustainability Compliance (%)'],
#       dtype='object')

# %%
dfm.dtypes
# Out:
# Material ID                                object
# Packaging Type                             object
# Material Type                              object
# Suitable Product Categories                object
# Recommended Packaging Use Cases            object
# Supplier Region                            object
# Recyclability (%)                           int64
# Recyclability Category                     object
# Recycled Content (%)                      float64
# Reusability (%)                           float64
# Biodegradation Time (days)                float64
# End-of-Life Disposal (%)                  float64
# Carbon Footprint (kg CO2/unit)            float64
# CO2 Emission per kg (estimated)           float64
# Waste Reduction Impact (%)                float64
# Sustainability Target Progress (%)        float64
# Load Handling Score                       float64
# Moisture Resistance Score                 float64
# Thermal Resistance Score                  float64
# ...

# %%
dfm.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
dfm.tail()
# Out:
#     Material ID           Packaging Type Material Type  \
# 399    MAT_0400  Plastic Totes & Pallets       Plastic
# 400    MAT_0401          Cardboard Boxes     Cardboard
# 401    MAT_0402  Plastic Totes & Pallets       Plastic
# 402    MAT_0403          Cardboard Boxes     Cardboard
# 403    MAT_0404  Plastic Totes & Pallets       Plastic
#
#                            Suitable Product Categories  \
# 399  Industrial Components, Heavy Machinery, Automo...
# 400  E-commerce, Food & Beverage, Consumer Goods, A...
# 401  Industrial Components, Heavy Machinery, Automo...
# 402  E-commerce, Food & Beverage, Consumer Goods, A...
# 403  Industrial Components, Heavy Machinery, Automo...
#
#                        Recommended Packaging Use Cases Supplier Region  \
# 399   Closed-loop logistics and bulk material handling        AMERICAS
# 400  Last-mile delivery and primary e-commerce pack...              EU
# 401   Closed-loop logistics and bulk material handling             ROW
# ...

# %% [markdown]
# # 2.2 Products

# %%
dfp.shape
# Out:
# (550, 6)

# %%
dfp.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'product_weight',
#        'fragility_index', 'shipping_type'],
#       dtype='object')

# %%
dfp.dtypes
# Out:
# product_id          object
# product_name        object
# category            object
# product_weight     float64
# fragility_index      int64
# shipping_type       object
# dtype: object

# %%
dfp.head()
# Out:
#   product_id            product_name    category  product_weight  \
# 0  PRD_20001      Water Bottle SKU-0      Sports        0.726424
# 1  PRD_20002  Area Rug (Small) SKU-1  Home Goods        1.425100
# 2  PRD_20003          Yoga Mat SKU-2      Sports        0.713777
# 3  PRD_20004    Hair Spray Can SKU-3   Cosmetics        0.387991
# 4  PRD_20005          Backpack SKU-4     Apparel        0.466723
#
#    fragility_index shipping_type
# 0                4           Air
# 1                5           Sea
# 2                2           Sea
# 3                3           Air
# 4                2           Sea

# %%
dfp.tail()
# Out:
#     product_id                  product_name    category  product_weight  \
# 545  PRD_20546  Water Filter Pitcher SKU-545  Home Goods        1.082720
# 546  PRD_20547          Water Bottle SKU-546      Sports        0.672879
# 547  PRD_20548      Antiseptic Wipes SKU-547    Pharmacy        0.187341
# 548  PRD_20549           Thermometer SKU-548    Pharmacy        0.191216
# 549  PRD_20550      Olive Oil Bottle SKU-549        Food        1.684140
#
#      fragility_index shipping_type
# 545                4           Air
# 546                2           Air
# 547                3           Sea
# 548                4          Road
# 549                3           Air

# %% [markdown]
# # 3.Summary Statistics

# %% [markdown]
# # 3.1 Materials

# %%
dfm.describe()
# Out:
#        Recyclability (%)  Recycled Content (%)  Reusability (%)  \
# count         404.000000            403.000000       403.000000
# mean           91.613861             61.833747        66.694789
# std             8.584966             19.340228        28.766147
# min            55.000000             21.000000         3.000000
# 25%            87.000000             47.500000        48.000000
# 50%            94.000000             68.000000        53.000000
# 75%            99.000000             79.000000        95.000000
# max           100.000000             94.000000       100.000000
#
#        Biodegradation Time (days)  End-of-Life Disposal (%)  \
# count                  403.000000                403.000000
# mean                 31396.910670                  9.039702
# std                  37072.185094                  5.561811
# min                     31.000000                  2.000000
# 25%                    197.000000                  5.000000
# ...

# %%
dfm.nunique()
# Out:
# Material ID                               404
# Packaging Type                              6
# Material Type                               4
# Suitable Product Categories                 6
# Recommended Packaging Use Cases             6
# Supplier Region                             6
# Recyclability (%)                          34
# Recyclability Category                      2
# Recycled Content (%)                       57
# Reusability (%)                            46
# Biodegradation Time (days)                160
# End-of-Life Disposal (%)                   15
# Carbon Footprint (kg CO2/unit)             99
# CO2 Emission per kg (estimated)            63
# Waste Reduction Impact (%)                 47
# Sustainability Target Progress (%)         38
# Load Handling Score                        10
# Moisture Resistance Score                  10
# Thermal Resistance Score                    9
# Cost per Unit (USD)                       144
# ...

# %%
dfm.value_counts()
# Out:
# Material ID  Packaging Type                            Material Type    Suitable Product Categories                                               Recommended Packaging Use Cases                                 Supplier Region  Recyclability (%)  Recyclability Category  Recycled Content (%)  Reusability (%)  Biodegradation Time (days)  End-of-Life Disposal (%)  Carbon Footprint (kg CO2/unit)  CO2 Emission per kg (estimated)  Waste Reduction Impact (%)  Sustainability Target Progress (%)  Load Handling Score  Moisture Resistance Score  Thermal Resistance Score  Cost per Unit (USD)  Annual Usage (units)  Total Material Weight (tons)  Supplier Sustainability Compliance (%)
# ...

# %% [markdown]
# # 3.2 products

# %%
dfp.describe()
# Out:
#        product_weight  fragility_index
# count      550.000000       550.000000
# mean         0.739147         3.385455
# std          0.449047         1.192175
# min          0.170669         1.000000
# 25%          0.364230         2.000000
# 50%          0.618680         3.000000
# 75%          1.188470         4.000000
# max          1.684140         5.000000

# %%
dfp.nunique()
# Out:
# product_id         550
# product_name       550
# category             7
# product_weight     197
# fragility_index      5
# shipping_type        3
# dtype: int64

# %%
dfp.value_counts()
# Out:
# product_id  product_name                   category    product_weight  fragility_index  shipping_type
# PRD_20550   Olive Oil Bottle SKU-549       Food        1.684140        3                Air              1
# PRD_20001   Water Bottle SKU-0             Sports      0.726424        4                Air              1
# PRD_20002   Area Rug (Small) SKU-1         Home Goods  1.425100        5                Sea              1
# PRD_20003   Yoga Mat SKU-2                 Sports      0.713777        2                Sea              1
# PRD_20004   Hair Spray Can SKU-3           Cosmetics   0.387991        3                Air              1
#                                                                                                         ..
# PRD_20011   Resistance Bands SKU-10        Sports      0.730312        2                Road             1
# PRD_20010   Essential Oils Diffuser SKU-9  Cosmetics   0.276229        5                Sea              1
# ...

# %% [markdown]
# # 4.Missing / Bad Data Analysis

# %% [markdown]
# # 4.1 Materials

# %%
mnull=dfm.isnull().sum()
mnull
# Out:
# Material ID                               0
# Packaging Type                            0
# Material Type                             0
# Suitable Product Categories               0
# Recommended Packaging Use Cases           0
# Supplier Region                           0
# Recyclability (%)                         0
# Recyclability Category                    0
# Recycled Content (%)                      1
# Reusability (%)                           1
# Biodegradation Time (days)                1
# End-of-Life Disposal (%)                  1
# Carbon Footprint (kg CO2/unit)            1
# CO2 Emission per kg (estimated)           1
# Waste Reduction Impact (%)                1
# Sustainability Target Progress (%)        1
# Load Handling Score                       1
# Moisture Resistance Score                 1
# Thermal Resistance Score                  1
# Cost per Unit (USD)                       1
# Annual Usage (units)                      1
# ...

# %%
dfm.duplicated().sum()
# Out:
# np.int64(0)

# %%
dfm[dfm["Recycled Content (%)"].isnull()]
# Out:
#     Material ID           Packaging Type Material Type  \
# 403    MAT_0404  Plastic Totes & Pallets       Plastic
#
#                            Suitable Product Categories  \
# 403  Industrial Components, Heavy Machinery, Automo...
#
#                       Recommended Packaging Use Cases Supplier Region  \
# 403  Closed-loop logistics and bulk material handling              EU
#
#      Recyclability (%) Recyclability Category  Recycled Content (%)  \
# 403                 95                 Medium                   NaN
#
#      Reusability (%)  ...  CO2 Emission per kg (estimated)  \
# 403              NaN  ...                              NaN
#
#      Waste Reduction Impact (%)  Sustainability Target Progress (%)  \
# 403                         NaN                                 NaN
#
#      Load Handling Score  Moisture Resistance Score  Thermal Resistance Score  \
# 403                  NaN                        NaN                       NaN
#
# ...

# %% [markdown]
# # 4.2 Products

# %%
pnull=dfp.isnull().sum()
pnull
# Out:
# product_id         0
# product_name       0
# category           0
# product_weight     0
# fragility_index    0
# shipping_type      0
# dtype: int64

# %%
dfp.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 5. Visualization

# %% [markdown]
# # 5.1 Materials

# %%
sns.histplot(dfm['Recyclability (%)'].dropna(), bins=15, kde=True, color='green')
# Out:
# <Axes: xlabel='Recyclability (%)', ylabel='Count'>

# %%
sns.boxplot(y=dfm["Cost per Unit (USD)"],color='skyblue')
# Out:
# <Axes: ylabel='Cost per Unit (USD)'>

# %%
sns.countplot(y=dfm["Suitable Product Categories"],data=dfm,palette='viridis')
plt.show()
# Out:
# C:\Users\A.L.N. Srinivas\AppData\Local\Temp\ipykernel_15532\45300578.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=dfm["Suitable Product Categories"],data=dfm,palette='viridis')

# %%
num=dfm.select_dtypes(include=np.number)
sns.heatmap(num.corr(),annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.show()

# %% [markdown]
# # 5.2 Products

# %%
sns.histplot(dfp["product_weight"].dropna(),bins=20,kde=True)
# Out:
# <Axes: xlabel='product_weight', ylabel='Count'>

# %%
sns.countplot(x='fragility_index', data=dfp, palette='flare')
# Out:
# C:\Users\A.L.N. Srinivas\AppData\Local\Temp\ipykernel_15532\718156005.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='fragility_index', data=dfp, palette='flare')
# <Axes: xlabel='fragility_index', ylabel='count'>

# %%
dfmmv=pd.DataFrame(mnull)
dfmmv.to_csv("materials_missing_value_count.csv",index=False)

# %%
dfpmv=pd.DataFrame(pnull)
dfpmv.to_csv("products_missing_value_count.csv",index=False)
