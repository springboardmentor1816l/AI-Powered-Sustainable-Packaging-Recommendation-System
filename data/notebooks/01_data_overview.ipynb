# %%
import pandas as pd

# %%
materials = pd.read_csv("C:\\Users\\sneha\\Desktop\\AI-Powered-Sustainable-Packaging-Recommendation-System\\data\\raw\\material_dataset.csv")
materials.head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
products = pd.read_csv("C:\\Users\\sneha\\Desktop\\AI-Powered-Sustainable-Packaging-Recommendation-System\\data\\raw\\product_dataset.csv")
products.head()
# Out:
#    product_id    product_name     category  product_weight_kg  \
# 0           1   Chocolate Box         Food                0.5
# 1           2      Smartphone  Electronics                0.3
# 2           3  Perfume Bottle    Cosmetics                0.2
# 3           4   Medicine Pack     Pharmacy                0.1
# 4           5      Snack Pack         Food                0.7
#
#    fragility_index shipping_type
# 0                2           Air
# 1                5           Air
# 2                4          Road
# 3                3           Air
# 4                2          Road

# %%
materials.shape
# Out:
# (404, 23)

# %%
products.shape
# Out:
# (1500, 6)

# %%
materials.columns
# Out:
# Index(['Material ID', 'Packaging Type', 'Material Type',
#        'Suitable Product Categories', 'Recommended Packaging Use Cases',
#        'Supplier Region', 'Recyclability (%)', 'Recyclability Category',
#        'Recycled Content (%)', 'Reusability (%)', 'Biodegradation Time (days)',
#        'End-of-Life Disposal (%)', 'Carbon Footprint (kg CO2/unit)',
#        'CO2 Emission per kg (estimated)', 'Waste Reduction Impact (%)',
#        'Sustainability Target Progress (%)', 'Load Handling Score',
#        'Moisture Resistance Score', 'Thermal Resistance Score',
#        'Cost per Unit (USD)', 'Annual Usage (units)',
#        'Total Material Weight (tons)',
#        'Supplier Sustainability Compliance (%)'],
#       dtype='object')

# %%
products.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'product_weight_kg',
#        'fragility_index', 'shipping_type'],
#       dtype='object')

# %%
materials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Material ID                             404 non-null    object
#  1   Packaging Type                          404 non-null    object
#  2   Material Type                           404 non-null    object
#  3   Suitable Product Categories             404 non-null    object
#  4   Recommended Packaging Use Cases         404 non-null    object
#  5   Supplier Region                         404 non-null    object
#  6   Recyclability (%)                       404 non-null    int64
#  7   Recyclability Category                  404 non-null    object
#  8   Recycled Content (%)                    403 non-null    float64
#  9   Reusability (%)                         403 non-null    float64
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1500 non-null   int64
#  1   product_name       1500 non-null   object
#  2   category           1500 non-null   object
#  3   product_weight_kg  1500 non-null   float64
#  4   fragility_index    1500 non-null   int64
#  5   shipping_type      1500 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 70.4+ KB

# %%
materials.isnull().sum()
# Out:
# Material ID                               0
# Packaging Type                            0
# Material Type                             0
# Suitable Product Categories               0
# Recommended Packaging Use Cases           0
# Supplier Region                           0
# Recyclability (%)                         0
# Recyclability Category                    0
# Recycled Content (%)                      1
# Reusability (%)                           1
# Biodegradation Time (days)                1
# End-of-Life Disposal (%)                  1
# Carbon Footprint (kg CO2/unit)            1
# CO2 Emission per kg (estimated)           1
# Waste Reduction Impact (%)                1
# Sustainability Target Progress (%)        1
# Load Handling Score                       1
# Moisture Resistance Score                 1
# Thermal Resistance Score                  1
# Cost per Unit (USD)                       1
# Annual Usage (units)                      1
# ...

# %%
products.isnull().sum()
# Out:
# product_id           0
# product_name         0
# category             0
# product_weight_kg    0
# fragility_index      0
# shipping_type        0
# dtype: int64

# %%
materials.describe()
# Out:
#        Recyclability (%)  Recycled Content (%)  Reusability (%)  \
# count         404.000000            403.000000       403.000000
# mean           91.613861             61.833747        66.694789
# std             8.584966             19.340228        28.766147
# min            55.000000             21.000000         3.000000
# 25%            87.000000             47.500000        48.000000
# 50%            94.000000             68.000000        53.000000
# 75%            99.000000             79.000000        95.000000
# max           100.000000             94.000000       100.000000
#
#        Biodegradation Time (days)  End-of-Life Disposal (%)  \
# count                  403.000000                403.000000
# mean                 31396.910670                  9.039702
# std                  37072.185094                  5.561811
# min                     31.000000                  2.000000
# 25%                    197.000000                  5.000000
# ...

# %%
products.describe()
# Out:
#         product_id  product_weight_kg  fragility_index
# count  1500.000000        1500.000000      1500.000000
# mean    750.500000           0.925087         2.617333
# std     433.157015           1.604414         1.087361
# min       1.000000           0.040000         1.000000
# 25%     375.750000           0.300000         2.000000
# 50%     750.500000           0.520000         3.000000
# 75%    1125.250000           0.900000         3.000000
# max    1500.000000          15.000000         5.000000

# %%
materials.select_dtypes(include='object').head()
# Out:
#   Material ID                            Packaging Type    Material Type  \
# 0    MAT_0001                           Cardboard Boxes        Cardboard
# 1    MAT_0002  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 2    MAT_0003                  Steel Racks & Containers            Steel
# 3    MAT_0004  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
# 4    MAT_0005  Protective Fillers (Paper/Biodegradable)  Paper/Bio-Based
#
#                          Suitable Product Categories  \
# 0  E-commerce, Food & Beverage, Consumer Goods, A...
# 1  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 2   Heavy Industrial Components, High-Security Goods
# 3  Fragile Items, Cosmetics, Pharmaceuticals, Int...
# 4  Fragile Items, Cosmetics, Pharmaceuticals, Int...
#
#                      Recommended Packaging Use Cases Supplier Region  \
# 0  Last-mile delivery and primary e-commerce pack...            EMEA
# ...

# %%
products.select_dtypes(include='object').head()
# Out:
#      product_name     category shipping_type
# 0   Chocolate Box         Food           Air
# 1      Smartphone  Electronics           Air
# 2  Perfume Bottle    Cosmetics          Road
# 3   Medicine Pack     Pharmacy           Air
# 4      Snack Pack         Food          Road

# %% [markdown]
# ## EDA Observations
#
# - Materials dataset has ___ rows and ___ columns
# - Products dataset has ___ rows and ___ columns
# - Some columns contain missing values
# - Numerical columns show varying ranges
# - Categorical columns contain text data
